# %% [markdown]
# <div style = 'text-align : center;'><h1>Marketing Insight Report</h1></div>
# <h4 style = 'text-align : center;'>by George E. Onwughalu</h4>

# %% [markdown]
# ## Introduction
# The dataset presented in this paper provides basic insights without delving into deep data analysis. It focuses on sales data from a Superstore, specifically targeting customers in the United States. The dataset includes details about the products shipped to various states and cities, highlighting the product category and sub-category for each shipment.
#
# In addition to geographic and product-related information, the dataset also records key metrics such as quantity, sales, discount applied, and the profit generated from each product. These features help offer a comprehensive overview of the store’s performance across different regions and product types, providing a foundation for further analysip>

# %% [markdown]
# ## Observations
# The dataset consists of thirteen (13) features or variables, with a total of nine thousand, nine hundred and ninety-four (9994) records. Out of the thirteen variables, five (5) are numerical, including Postal Code, Sales, Quantity, Discount, and Profit, while the remaining variables are categorical.
#
# The mean values for Sales, Quantity, Discount, and Profit are approximately 230, 3.79, 0.16, and 28.66, respectively. The maximum values for these variables are 22,638.48 for Sales, 14.00 for Quantity, 0.80 for Discount, and 8,399.77 for Pfit.
#
# The diagrams below illustrates the total `Sales` and `Profit` made by each category.ies.

# %% [markdown]
# ![Sales_Category_2.png](attachment:88cea455-9d19-4d33-bca3-04361a2d3e67.png) ![Profit_Category_2.png](attachment:0dfe1d1a-8922-4843-811d-f2fcd56a0a53.png)

# %% [markdown]
# The technological product category has the highest total sales of $836154 $ and profit of $145,455,$ all in usd.

# %% [markdown]
# The top three selling products considering in general the three categories are `Phones` with total sales of $330007, $ `Chairs` with the total sales of $328449,$ and `Storage` with the total sales of $223844$ in usd.

# %% [markdown]
# ![Top_Selling_Products.png](attachment:8d996a0e-30c7-477f-a764-b3676fbbe3f9.png)

# %% [markdown]
# The table below ranks the products based on profitability, starting from the highest.

# %% [markdown]
# ![Top_Profitable Product.png](attachment:c0431044-a935-462a-9531-73458ce35adc.png)

# %% [markdown]
# ## Conclusion
# Based on the insights above, it is evident that, in general, phones emerge as the top-performing product when evaluating both total sales and profitability. Their strong performance stands out across multiple metrics, indicating a robust demand and significant contribution to the overall revenue. The consistent sales figures, coupled with a healthy profit margin, suggest that phones not only sell well but also generate a substantial return, making them a key product category for continued focus and potential growth.
#
# However, further analysis is necessary to investigate the product category "Furniture," which shows a paradoxical trend of high sales accompanied by very low profit margins. This discrepancy warrants a deeper examination to understand the underlying factors contributing to the low profitability. It could involve exploring aspects such as high production or shipping costs, pricing strategies, or perhaps inventory management issues. By delving into these variables, a clearer picture can be formed, potentially uncovering areas for improvement and optimization within the furniture category.

# %% [markdown]
# This project is part of my internship at HNG, where I’m gaining hands-on experience. Here’s some more information about the organization:
# * [HNG Internship](https://hng.tech/internship)
# * [Hire HNG Analysts](https://hng.tech/hire/data-analysts)
